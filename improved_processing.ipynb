# %%
import json
import os
from typing import List, Dict
from langchain.text_splitter import RecursiveCharacterTextSplitter
import re

def load_json_file(file_path: str) -> Dict:
    """Load a JSON file and return its contents as a dictionary."""
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

def clean_text(text: str) -> str:
    """Clean the text by removing extra whitespace and certain patterns."""
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text.strip())
    # Add more cleaning steps as needed
    return text

def split_transcript(transcript: str, max_tokens: int = 512, chunk_overlap: int = 100) -> List[str]:
    """Split the transcript into chunks."""
    # Assuming 1 token is approximately 4 characters
    chunk_size = max_tokens * 4
    
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        separators=["\n\n", "\n", ". ", "!", "?", ",", " ", ""],
        keep_separator=False,
    )
    
    return text_splitter.split_text(transcript)

def create_enriched_chunks(video_data: Dict, max_tokens: int = 512, chunk_overlap: int = 100) -> List[Dict]:
    """Create enriched chunks from video data."""
    transcript = clean_text(video_data['transcript'])
    chunks = split_transcript(transcript, max_tokens, chunk_overlap)
    
    enriched_chunks = []
    for i, chunk in enumerate(chunks):
        enriched_chunk = {
            "content": chunk,
            "metadata": {
                "video_id": video_data["id"],
                "title": video_data["title"],
                "upload_date": video_data["upload_date"],
                "chunk_number": f"{i+1} of {len(chunks)}",
                "thumbnail_url": video_data["thumbnail_url"]
            }
        }
        enriched_chunks.append(enriched_chunk)
    
    return enriched_chunks

def process_all_videos(input_directory: str, output_directory: str, max_tokens: int = 512, chunk_overlap: int = 100):
    """Process all video JSON files in the input directory and save enriched chunks."""
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    for filename in os.listdir(input_directory):
        if filename.endswith('.json'):
            input_path = os.path.join(input_directory, filename)
            output_path = os.path.join(output_directory, f"enriched_{filename}")
            
            video_data = load_json_file(input_path)
            enriched_chunks = create_enriched_chunks(video_data, max_tokens, chunk_overlap)
            
            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(enriched_chunks, f, ensure_ascii=False, indent=2)

    print(f"Processed files saved in {output_directory}")

# Example usage
if __name__ == "__main__":
    input_dir = r"E:\Udemy\fitness-podcastai\src\data_collection\data\raw"
    output_dir = r"E:\Udemy\fitness-podcastai\src\data_collection\data\raw\chunks"
    max_tokens = 512  # Adjust as needed
    chunk_overlap = 100  # Adjust as needed
    
    process_all_videos(input_dir, output_dir, max_tokens, chunk_overlap)
# Out:
# Processed files saved in E:\Udemy\fitness-podcastai\src\data_collection\data\raw\chunks

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key=os.environ.get("PINECONE_API_KEY"))

# %%
import os
from pinecone import Pinecone, ServerlessSpec
from sentence_transformers import SentenceTransformer
import json
import time

# Initialize Pinecone
pc = Pinecone(api_key=os.environ.get("PINECONE_API_KEY"))

index_name = "fitness-chatbot"

# Check if the index already exists
if index_name not in pc.list_indexes().names():
    print(f"Creating new index: {index_name}")
    pc.create_index(
        name=index_name,
        dimension=768,  # dimension for 'multi-qa-mpnet-base-dot-v1'
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )
    print("Waiting for index to be ready...")
    time.sleep(60)  # Wait for 60 seconds to ensure index is ready
else:
    print(f"Index {index_name} already exists")

# Get the index
index = pc.Index(index_name)

# Initialize the embedding model
model = SentenceTransformer('multi-qa-mpnet-base-dot-v1')

def generate_embedding(text):
    return model.encode(text)

def process_and_store_embeddings(input_dir):
    total_vectors = 0
    for filename in os.listdir(input_dir):
        if filename.endswith('.json'):
            try:
                with open(os.path.join(input_dir, filename), 'r', encoding='utf-8') as f:
                    chunks = json.load(f)
                
                print(f"Processing {filename} with {len(chunks)} chunks")
                
                vectors_to_upsert = []
                for chunk in chunks:
                    embedding = generate_embedding(chunk['content'])
                    vector_id = f"{chunk['metadata']['video_id']}_{chunk['metadata']['chunk_number']}"
                    vectors_to_upsert.append((vector_id, embedding.tolist(), chunk['metadata']))
                
                # Upsert to Pinecone in batches
                batch_size = 100
                for i in range(0, len(vectors_to_upsert), batch_size):
                    batch = vectors_to_upsert[i:i+batch_size]
                    try:
                        upsert_response = index.upsert(vectors=batch)
                        print(f"Upserted batch {i//batch_size + 1}. Response: {upsert_response}")
                        total_vectors += len(batch)
                    except Exception as e:
                        print(f"Error upserting batch: {str(e)}")
                
                print(f"Processed and stored embeddings for {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {str(e)}")

    print(f"Finished processing all chunks in {input_dir}")
    print(f"Total vectors upserted: {total_vectors}")
    return total_vectors

def count_total_vectors():
    stats = index.describe_index_stats()
    return stats['total_vector_count']

# Usage
input_dir = r"E:\Udemy\fitness-podcastai\src\data_collection\data\raw\chunks"
total_upserted = process_and_store_embeddings(input_dir)

print("Waiting for 60 seconds before checking total vectors...")
time.sleep(60)  # Wait for 60 seconds to ensure all updates are reflected

total_vectors = count_total_vectors()
print(f"Total vectors in index: {total_vectors}")

if total_vectors != total_upserted:
    print(f"Warning: Upserted {total_upserted} vectors, but index shows {total_vectors} vectors")
# Out:
# Index fitness-chatbot already exists
# Processing enriched_-2FesPR4WEQ.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_-2FesPR4WEQ.json
# Processing enriched_-5T82eXSYvY.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_-5T82eXSYvY.json
# Processing enriched_-9OWV6kio94.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_-9OWV6kio94.json
# Processing enriched_-bP24FFkQ54.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_-bP24FFkQ54.json
# Processing enriched_-BzNffL_6YE.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_-BzNffL_6YE.json
# Processing enriched_-CHmorGmjmg.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_-CHmorGmjmg.json
# Processing enriched_-hYld_0TT_4.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_-hYld_0TT_4.json
# Processing enriched_-JtCWq1M5qY.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_-JtCWq1M5qY.json
# Processing enriched_-Mbr55h3BeQ.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_-Mbr55h3BeQ.json
# Processing enriched_-OMrl5Pnoxg.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_-OMrl5Pnoxg.json
# Processing enriched_-qn7b0z--fU.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_-qn7b0z--fU.json
# Processing enriched_-T64FLsJnAU.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_-T64FLsJnAU.json
# Processing enriched_-VdTS9HF1mY.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_-VdTS9HF1mY.json
# Processing enriched_02W0832OQos.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_02W0832OQos.json
# Processing enriched_07AXhucRMbE.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_07AXhucRMbE.json
# Processing enriched_08RCq776pw0.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_08RCq776pw0.json
# Processing enriched_09CZPfbxGRc.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_09CZPfbxGRc.json
# Processing enriched_0ckfCxEV-bs.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_0ckfCxEV-bs.json
# Processing enriched_0FIu_06FmsY.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_0FIu_06FmsY.json
# Processing enriched_0KGeuDxYAlg.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_0KGeuDxYAlg.json
# Processing enriched_0ntdqhGtJ2I.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_0ntdqhGtJ2I.json
# Processing enriched_0oIacYXv0bw.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_0oIacYXv0bw.json
# Processing enriched_0S39jEKmky0.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_0S39jEKmky0.json
# Processing enriched_0U4XgPQnLdc.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_0U4XgPQnLdc.json
# Processing enriched_0XQr6QFPJgk.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_0XQr6QFPJgk.json
# Processing enriched_0XwwoHEMXso.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_0XwwoHEMXso.json
# Processing enriched_155cGWBbWEA.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_155cGWBbWEA.json
# Processing enriched_16ZFEUpFEv4.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_16ZFEUpFEv4.json
# Processing enriched_18ZQtCZrvzA.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_18ZQtCZrvzA.json
# Processing enriched_1AjcZ1kiPyI.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_1AjcZ1kiPyI.json
# Processing enriched_1Cbu2PkQnro.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_1Cbu2PkQnro.json
# Processing enriched_1DINSG8mVFs.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_1DINSG8mVFs.json
# Processing enriched_1dw0CKiDvGY.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_1dw0CKiDvGY.json
# Processing enriched_1E9pRu43A-8.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_1E9pRu43A-8.json
# Processing enriched_1i3bU5zV8sI.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_1i3bU5zV8sI.json
# Processing enriched_1iODncOLJnk.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_1iODncOLJnk.json
# Processing enriched_1jp2uhfO8M0.json with 12 chunks
# Upserted batch 1. Response: {'upserted_count': 12}
# Processed and stored embeddings for enriched_1jp2uhfO8M0.json
# Processing enriched_1NJvPoeL938.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_1NJvPoeL938.json
# Processing enriched_1OF3q6MHie8.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_1OF3q6MHie8.json
# Processing enriched_1sNTW4nnF_Y.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_1sNTW4nnF_Y.json
# Processing enriched_1TP9BKqk_gs.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_1TP9BKqk_gs.json
# Processing enriched_1vsWC6ao_To.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_1vsWC6ao_To.json
# Processing enriched_274pf8-Zev8.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_274pf8-Zev8.json
# Processing enriched_27waZSngzW8.json with 11 chunks
# Upserted batch 1. Response: {'upserted_count': 11}
# Processed and stored embeddings for enriched_27waZSngzW8.json
# Processing enriched_287LWsmCrGQ.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_287LWsmCrGQ.json
# Processing enriched_2a0dDuZOyl0.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_2a0dDuZOyl0.json
# Processing enriched_2AdC21CNuBI.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_2AdC21CNuBI.json
# Processing enriched_2fIw6UYn25c.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_2fIw6UYn25c.json
# Processing enriched_2GG4Qi5whnA.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_2GG4Qi5whnA.json
# Processing enriched_2hKbghN2fUE.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_2hKbghN2fUE.json
# Processing enriched_2huvkWzPRps.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_2huvkWzPRps.json
# Processing enriched_2J5Fz9GkgTQ.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_2J5Fz9GkgTQ.json
# Processing enriched_2J9C7rO5aUI.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_2J9C7rO5aUI.json
# Processing enriched_2N5P_iWkluQ.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_2N5P_iWkluQ.json
# Processing enriched_2Nxct9Sqdn4.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_2Nxct9Sqdn4.json
# Processing enriched_2OD1gjN5BWg.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_2OD1gjN5BWg.json
# Processing enriched_2oxruLoiGhI.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_2oxruLoiGhI.json
# Processing enriched_2qwrt3V5A1Y.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_2qwrt3V5A1Y.json
# Processing enriched_2SZ3B3Tqvh4.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_2SZ3B3Tqvh4.json
# Processing enriched_2TMfyZGdV7I.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_2TMfyZGdV7I.json
# Processing enriched_2tnwYYYAK4o.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_2tnwYYYAK4o.json
# Processing enriched_2X7LDuBcPMw.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_2X7LDuBcPMw.json
# Processing enriched_2X97ZWux7L4.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_2X97ZWux7L4.json
# Processing enriched_2xaqqI1eTX0.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_2xaqqI1eTX0.json
# Processing enriched_2xJIw_zE46I.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_2xJIw_zE46I.json
# Processing enriched_2Xw5yE7EDho.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_2Xw5yE7EDho.json
# Processing enriched_2zLha_2AG0c.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_2zLha_2AG0c.json
# Processing enriched_2_1ylJ-9twY.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_2_1ylJ-9twY.json
# Processing enriched_31tCf8Spy2c.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_31tCf8Spy2c.json
# Processing enriched_330Ufcaj1zA.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_330Ufcaj1zA.json
# Processing enriched_33C2eerC_PA.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_33C2eerC_PA.json
# Processing enriched_34zG7LFdwq0.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_34zG7LFdwq0.json
# Processing enriched_35N7cnN0vTM.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_35N7cnN0vTM.json
# Processing enriched_36636A30XCg.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_36636A30XCg.json
# Processing enriched_3aRpAO6bfvA.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_3aRpAO6bfvA.json
# Processing enriched_3eOFjmSM9s8.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_3eOFjmSM9s8.json
# Processing enriched_3h1TVVwXabc.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_3h1TVVwXabc.json
# Processing enriched_3jTwNTm1EBE.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_3jTwNTm1EBE.json
# Processing enriched_3jVfAywaiOE.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_3jVfAywaiOE.json
# Processing enriched_3NDAysp5n5M.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_3NDAysp5n5M.json
# Processing enriched_3R7VaPa3nIo.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_3R7VaPa3nIo.json
# Processing enriched_3RuPQ9VW_x8.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_3RuPQ9VW_x8.json
# Processing enriched_3U0Q0lKDrxQ.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_3U0Q0lKDrxQ.json
# Processing enriched_3wqXNZbnZEs.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_3wqXNZbnZEs.json
# Processing enriched_3wzdCh5QRYI.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_3wzdCh5QRYI.json
# Processing enriched_3YWm4LyW32c.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_3YWm4LyW32c.json
# Processing enriched_4EkKhkSNjWY.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_4EkKhkSNjWY.json
# Processing enriched_4FDhad2i-o4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_4FDhad2i-o4.json
# Processing enriched_4gQhdqo7LmY.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_4gQhdqo7LmY.json
# Processing enriched_4iXRhYlivdI.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_4iXRhYlivdI.json
# Processing enriched_4JE-wdA3PHw.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_4JE-wdA3PHw.json
# Processing enriched_4KmkN_Fzoqc.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_4KmkN_Fzoqc.json
# Processing enriched_4KwhbHsnj6Q.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_4KwhbHsnj6Q.json
# Processing enriched_4pC9DKPGklo.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_4pC9DKPGklo.json
# Processing enriched_4pET4k_vtI4.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_4pET4k_vtI4.json
# Processing enriched_4Qc5pGZ9uYM.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_4Qc5pGZ9uYM.json
# Processing enriched_4xqOc4hJu94.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_4xqOc4hJu94.json
# Processing enriched_5-GskNrg3UY.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_5-GskNrg3UY.json
# Processing enriched_50ZzYbCbkOU.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_50ZzYbCbkOU.json
# Processing enriched_54krdTEyziQ.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_54krdTEyziQ.json
# Processing enriched_54yBZLiQNT4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_54yBZLiQNT4.json
# Processing enriched_59WTOLAmE3k.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_59WTOLAmE3k.json
# Processing enriched_5AGXyd90p9o.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_5AGXyd90p9o.json
# Processing enriched_5AjdUpUpWXc.json with 10 chunks
# Upserted batch 1. Response: {'upserted_count': 10}
# Processed and stored embeddings for enriched_5AjdUpUpWXc.json
# Processing enriched_5B5MZQuztK4.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_5B5MZQuztK4.json
# Processing enriched_5DfCBBPgxE0.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_5DfCBBPgxE0.json
# Processing enriched_5edrBwGc51o.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_5edrBwGc51o.json
# Processing enriched_5fbLq2gIDA8.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_5fbLq2gIDA8.json
# Processing enriched_5h_Ig6hLBIc.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_5h_Ig6hLBIc.json
# Processing enriched_5I3LgiumTJM.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_5I3LgiumTJM.json
# Processing enriched_5ihi0QG-rCM.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_5ihi0QG-rCM.json
# Processing enriched_5J8RIIvEj6k.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_5J8RIIvEj6k.json
# Processing enriched_5K9haadfKf8.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_5K9haadfKf8.json
# Processing enriched_5n43lnn5QUE.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_5n43lnn5QUE.json
# Processing enriched_5Nh8ulyzv7Q.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_5Nh8ulyzv7Q.json
# Processing enriched_5OSHCWv_rjg.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_5OSHCWv_rjg.json
# Processing enriched_5PsCMjseTZA.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_5PsCMjseTZA.json
# Processing enriched_5qVd7_O5ifY.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_5qVd7_O5ifY.json
# Processing enriched_5RMfId_3Tdc.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_5RMfId_3Tdc.json
# Processing enriched_5sHsJJM4nZU.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_5sHsJJM4nZU.json
# Processing enriched_5tvJPnp6x40.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_5tvJPnp6x40.json
# Processing enriched_5x7rR-bz0Rg.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_5x7rR-bz0Rg.json
# Processing enriched_5YYb9vyj6zQ.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_5YYb9vyj6zQ.json
# Processing enriched_5zmlnbWb-g4.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_5zmlnbWb-g4.json
# Processing enriched_5ZVvtfqoaY4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_5ZVvtfqoaY4.json
# Processing enriched_5_au4UOs4mw.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_5_au4UOs4mw.json
# Processing enriched_6-9TzTYFqyY.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_6-9TzTYFqyY.json
# Processing enriched_6209o2i2Mk8.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_6209o2i2Mk8.json
# Processing enriched_63J2-MpRomQ.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_63J2-MpRomQ.json
# Processing enriched_64cXpMTv6CE.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_64cXpMTv6CE.json
# Processing enriched_6BFJJjqLks4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_6BFJJjqLks4.json
# Processing enriched_6CZPFulZl-g.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_6CZPFulZl-g.json
# Processing enriched_6EzsrdPIP0I.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_6EzsrdPIP0I.json
# Processing enriched_6g57DJntRXk.json with 11 chunks
# Upserted batch 1. Response: {'upserted_count': 11}
# Processed and stored embeddings for enriched_6g57DJntRXk.json
# Processing enriched_6gfh2UfcJFw.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_6gfh2UfcJFw.json
# Processing enriched_6HKMTQgLC9k.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_6HKMTQgLC9k.json
# Processing enriched_6hzuAhSg89Q.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_6hzuAhSg89Q.json
# Processing enriched_6IQZcaVGJAc.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_6IQZcaVGJAc.json
# Processing enriched_6lnCP4z_dGk.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_6lnCP4z_dGk.json
# Processing enriched_6lV-kpBEOg0.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_6lV-kpBEOg0.json
# Processing enriched_6m-NtbKhxZQ.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_6m-NtbKhxZQ.json
# Processing enriched_6MR7uBRVnZg.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_6MR7uBRVnZg.json
# Processing enriched_6P9dJbMRKgo.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_6P9dJbMRKgo.json
# Processing enriched_6pKKnVg1hzE.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_6pKKnVg1hzE.json
# Processing enriched_6QgR6Tjle7g.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_6QgR6Tjle7g.json
# Processing enriched_6QRdA7gl8mk.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_6QRdA7gl8mk.json
# Processing enriched_6Qrr0GLeGp0.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_6Qrr0GLeGp0.json
# Processing enriched_6rDbWw5js8s.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_6rDbWw5js8s.json
# Processing enriched_6rr5p1jCZC4.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_6rr5p1jCZC4.json
# Processing enriched_6V5tSn9oEJg.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_6V5tSn9oEJg.json
# Processing enriched_6x9-5m2Vodo.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_6x9-5m2Vodo.json
# Processing enriched_6xZpHv67rD8.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_6xZpHv67rD8.json
# Processing enriched_6yp_-GcB4ew.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_6yp_-GcB4ew.json
# Processing enriched_71NiUvA_nlo.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_71NiUvA_nlo.json
# Processing enriched_72p58Iy6u7M.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_72p58Iy6u7M.json
# Processing enriched_73htR_-B-HI.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_73htR_-B-HI.json
# Processing enriched_73nxqzkCUy0.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_73nxqzkCUy0.json
# Processing enriched_7bo3RaOEL8g.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_7bo3RaOEL8g.json
# Processing enriched_7CfFSUUS8HM.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_7CfFSUUS8HM.json
# Processing enriched_7dT4KHtMM-A.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_7dT4KHtMM-A.json
# Processing enriched_7fICF_O5esc.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_7fICF_O5esc.json
# Processing enriched_7IB1AUnLuLs.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_7IB1AUnLuLs.json
# Processing enriched_7KG5UCkNU9U.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_7KG5UCkNU9U.json
# Processing enriched_7kTNk3qEuLM.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_7kTNk3qEuLM.json
# Processing enriched_7Nu7eSe9KHQ.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_7Nu7eSe9KHQ.json
# Processing enriched_7nuTmFy-qBg.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_7nuTmFy-qBg.json
# Processing enriched_7oKWugCTFMY.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_7oKWugCTFMY.json
# Processing enriched_7PWKmPmYGQw.json with 10 chunks
# Upserted batch 1. Response: {'upserted_count': 10}
# Processed and stored embeddings for enriched_7PWKmPmYGQw.json
# Processing enriched_7qPYYw3lPSA.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_7qPYYw3lPSA.json
# Processing enriched_7R88yqmcGrw.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_7R88yqmcGrw.json
# Processing enriched_7rEumOahfds.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_7rEumOahfds.json
# Processing enriched_8686PLZB_1Q.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_8686PLZB_1Q.json
# Processing enriched_8bjtwSB8fVY.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_8bjtwSB8fVY.json
# Processing enriched_8bshv_9HWw4.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_8bshv_9HWw4.json
# Processing enriched_8B_uf-lR8cI.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_8B_uf-lR8cI.json
# Processing enriched_8dbPdH0pIBI.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_8dbPdH0pIBI.json
# Processing enriched_8fvT3sYfzLo.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_8fvT3sYfzLo.json
# Processing enriched_8jyhJ6TiUPA.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_8jyhJ6TiUPA.json
# Processing enriched_8Ki5gtfleCc.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_8Ki5gtfleCc.json
# Processing enriched_8lJ42tf-iqw.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_8lJ42tf-iqw.json
# Processing enriched_8lQzkwqhKTk.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_8lQzkwqhKTk.json
# Processing enriched_8mOjYFwmgxk.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_8mOjYFwmgxk.json
# Processing enriched_8nEmsR68FhA.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_8nEmsR68FhA.json
# Processing enriched_8r-wIB9jlE4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_8r-wIB9jlE4.json
# Processing enriched_8S4aLmSp3dg.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_8S4aLmSp3dg.json
# Processing enriched_8SZwREN9YtA.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_8SZwREN9YtA.json
# Processing enriched_8uRdMSDyAJY.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_8uRdMSDyAJY.json
# Processing enriched_8zUEUBRd6b0.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_8zUEUBRd6b0.json
# Processing enriched_9-GNGg7tqUk.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_9-GNGg7tqUk.json
# Processing enriched_92cjFZzTuVM.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_92cjFZzTuVM.json
# Processing enriched_95hX_OMuIpg.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_95hX_OMuIpg.json
# Processing enriched_9Aun7oeWSlM.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_9Aun7oeWSlM.json
# Processing enriched_9boaIRTLnns.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_9boaIRTLnns.json
# Processing enriched_9DqQ5GfZth4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_9DqQ5GfZth4.json
# Processing enriched_9FoG84EH8Jw.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_9FoG84EH8Jw.json
# Processing enriched_9gHRFByJnY8.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_9gHRFByJnY8.json
# Processing enriched_9gR7SCiV6AQ.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_9gR7SCiV6AQ.json
# Processing enriched_9hQCaQBfMcY.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_9hQCaQBfMcY.json
# Processing enriched_9JjwnkA3XJs.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_9JjwnkA3XJs.json
# Processing enriched_9K9lTOQ8uEM.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_9K9lTOQ8uEM.json
# Processing enriched_9llvBAV4RHI.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_9llvBAV4RHI.json
# Processing enriched_9mYdsMCKaHc.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_9mYdsMCKaHc.json
# Processing enriched_9n1OGTqCyeI.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_9n1OGTqCyeI.json
# Processing enriched_9O--R7E32jw.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_9O--R7E32jw.json
# Processing enriched_9orhHGlure4.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_9orhHGlure4.json
# Processing enriched_9PLvTHeuot8.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_9PLvTHeuot8.json
# Processing enriched_9SKuFe2SERs.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_9SKuFe2SERs.json
# Processing enriched_9Su3Nu9C9Z8.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_9Su3Nu9C9Z8.json
# Processing enriched_9TGhtatQeag.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_9TGhtatQeag.json
# Processing enriched_9v8zrMD1Qbg.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_9v8zrMD1Qbg.json
# Processing enriched_9VsDP584zyQ.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_9VsDP584zyQ.json
# Processing enriched_9XP_pmTwYsw.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_9XP_pmTwYsw.json
# Processing enriched_9yzYzWYtkvI.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_9yzYzWYtkvI.json
# Processing enriched_9_TsNeX2IXo.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_9_TsNeX2IXo.json
# Processing enriched_A2nerwXm9d4.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_A2nerwXm9d4.json
# Processing enriched_A2pcU2XDn1s.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_A2pcU2XDn1s.json
# Processing enriched_A3uK5TPzHq8.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_A3uK5TPzHq8.json
# Processing enriched_a3WfZhLdxIM.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_a3WfZhLdxIM.json
# Processing enriched_a68qDHDmwqg.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_a68qDHDmwqg.json
# Processing enriched_a6jkHbYyHgk.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_a6jkHbYyHgk.json
# Processing enriched_A7qBhMKvIiQ.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_A7qBhMKvIiQ.json
# Processing enriched_a9_JPgwW9nw.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_a9_JPgwW9nw.json
# Processing enriched_aadFfsnsdQ8.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_aadFfsnsdQ8.json
# Processing enriched_AADG66TfLfI.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_AADG66TfLfI.json
# Processing enriched_AAjlNtI1NiI.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_AAjlNtI1NiI.json
# Processing enriched_AB5yJWn-Yik.json with 11 chunks
# Upserted batch 1. Response: {'upserted_count': 11}
# Processed and stored embeddings for enriched_AB5yJWn-Yik.json
# Processing enriched_aBgv30fkD7c.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_aBgv30fkD7c.json
# Processing enriched_aBtQ2dGn_Ls.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_aBtQ2dGn_Ls.json
# Processing enriched_AbXv8vb0FRM.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_AbXv8vb0FRM.json
# Processing enriched_AcIutBGMfHg.json with 10 chunks
# Upserted batch 1. Response: {'upserted_count': 10}
# Processed and stored embeddings for enriched_AcIutBGMfHg.json
# Processing enriched_AD6YTTb5WQY.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_AD6YTTb5WQY.json
# Processing enriched_AD_FwNODCD8.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_AD_FwNODCD8.json
# Processing enriched_Ae0f-fiJ5SU.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_Ae0f-fiJ5SU.json
# Processing enriched_Ae81rtoBpOw.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_Ae81rtoBpOw.json
# Processing enriched_aFQaJ6-T_6o.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_aFQaJ6-T_6o.json
# Processing enriched_aG7n4XLM-Ek.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_aG7n4XLM-Ek.json
# Processing enriched_AgC7p14h3rY.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_AgC7p14h3rY.json
# Processing enriched_aGe2j-nOjxU.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_aGe2j-nOjxU.json
# Processing enriched_agF7TbWjQao.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_agF7TbWjQao.json
# Processing enriched_AII23B8YjiY.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_AII23B8YjiY.json
# Processing enriched_aImW4d9BnaQ.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_aImW4d9BnaQ.json
# Processing enriched_AjCwi_ecQcc.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_AjCwi_ecQcc.json
# Processing enriched_aKJgMqOMAb0.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_aKJgMqOMAb0.json
# Processing enriched_aL_8v_cGdCc.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_aL_8v_cGdCc.json
# Processing enriched_AMFERuFVzkM.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_AMFERuFVzkM.json
# Processing enriched_aMl-lNOKAEI.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_aMl-lNOKAEI.json
# Processing enriched_AMn59IKSgRw.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_AMn59IKSgRw.json
# Processing enriched_Aom1uaythK8.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_Aom1uaythK8.json
# Processing enriched_aPMwIa-qVPg.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_aPMwIa-qVPg.json
# Processing enriched_aQyI2e7ow4w.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_aQyI2e7ow4w.json
# Processing enriched_aR9I7q2wR8o.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_aR9I7q2wR8o.json
# Processing enriched_ArRmzy_ckOQ.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_ArRmzy_ckOQ.json
# Processing enriched_arZJ0-wGZqk.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_arZJ0-wGZqk.json
# Processing enriched_AscZRiHwHFs.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_AscZRiHwHFs.json
# Processing enriched_At8PRTDDhrU.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_At8PRTDDhrU.json
# Processing enriched_auGffH3rrK4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_auGffH3rrK4.json
# Processing enriched_auy0ojdCD2I.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_auy0ojdCD2I.json
# Processing enriched_AvuljWzTuRk.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_AvuljWzTuRk.json
# Processing enriched_Aw5EfLi4JGo.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_Aw5EfLi4JGo.json
# Processing enriched_AWjC3YZl5S8.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_AWjC3YZl5S8.json
# Processing enriched_AwJvb8LqhE8.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_AwJvb8LqhE8.json
# Processing enriched_a_gLYLFkjiw.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_a_gLYLFkjiw.json
# Processing enriched_B3XFTkKAkac.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_B3XFTkKAkac.json
# Processing enriched_B8LRBUkarAE.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_B8LRBUkarAE.json
# Processing enriched_BaACJok0T48.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_BaACJok0T48.json
# Processing enriched_BEAc-Ds7zJw.json with 10 chunks
# Upserted batch 1. Response: {'upserted_count': 10}
# Processed and stored embeddings for enriched_BEAc-Ds7zJw.json
# Processing enriched_bGOE2LOU8n4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_bGOE2LOU8n4.json
# Processing enriched_bHfABTsu0dM.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_bHfABTsu0dM.json
# Processing enriched_bku7gqPbw8Y.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_bku7gqPbw8Y.json
# Processing enriched_BMbQUdyKTRM.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_BMbQUdyKTRM.json
# Processing enriched_bmUMRnvAucw.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_bmUMRnvAucw.json
# Processing enriched_BnGvgbDzheQ.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_BnGvgbDzheQ.json
# Processing enriched_bOJu7xi3l3Q.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_bOJu7xi3l3Q.json
# Processing enriched_BpbZC_Pd4XU.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_BpbZC_Pd4XU.json
# Processing enriched_Bq6NcAoQDSk.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_Bq6NcAoQDSk.json
# Processing enriched_bqmW02csD6g.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_bqmW02csD6g.json
# Processing enriched_BQOJ-aqclFs.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_BQOJ-aqclFs.json
# Processing enriched_BR1sPQVrjrI.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_BR1sPQVrjrI.json
# Processing enriched_BRBVKxMb1RQ.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_BRBVKxMb1RQ.json
# Processing enriched_bt-IQFsvNPQ.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_bt-IQFsvNPQ.json
# Processing enriched_bt1woAP3LdE.json with 13 chunks
# Upserted batch 1. Response: {'upserted_count': 13}
# Processed and stored embeddings for enriched_bt1woAP3LdE.json
# Processing enriched_BvtD3znOqao.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_BvtD3znOqao.json
# Processing enriched_bx9SssAikQo.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_bx9SssAikQo.json
# Processing enriched_bXVeJaa4WcM.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_bXVeJaa4WcM.json
# Processing enriched_BY13DFmEF-s.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_BY13DFmEF-s.json
# Processing enriched_BZ1TUVr4LFk.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_BZ1TUVr4LFk.json
# Processing enriched_Bz3AG-oCXTE.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_Bz3AG-oCXTE.json
# Processing enriched_bZq2D3kdwdY.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_bZq2D3kdwdY.json
# Processing enriched_B_sukFC6Nn8.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_B_sukFC6Nn8.json
# Processing enriched_C1hTEMtvltw.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_C1hTEMtvltw.json
# Processing enriched_c2bof21Me3I.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_c2bof21Me3I.json
# Processing enriched_C3qPBk9C_uc.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_C3qPBk9C_uc.json
# Processing enriched_C44XXEQSi_M.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_C44XXEQSi_M.json
# Processing enriched_c5RmFuhMW3E.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_c5RmFuhMW3E.json
# ...
# Processed and stored embeddings for enriched_y1r9toPQNkM.json
# Processing enriched_Y2KbkJIEWZg.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_Y2KbkJIEWZg.json
# Processing enriched_Y2vZMSVqydQ.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_Y2vZMSVqydQ.json
# Processing enriched_Y3PL7Eyg7og.json with 12 chunks
# Upserted batch 1. Response: {'upserted_count': 12}
# Processed and stored embeddings for enriched_Y3PL7Eyg7og.json
# Processing enriched_y5BpvYGyVb0.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_y5BpvYGyVb0.json
# Processing enriched_Y6ubG5fZhIk.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_Y6ubG5fZhIk.json
# Processing enriched_y7A35FBwb04.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_y7A35FBwb04.json
# Processing enriched_Yado7bCCm2o.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_Yado7bCCm2o.json
# Processing enriched_YAUGMT0_PiE.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_YAUGMT0_PiE.json
# Processing enriched_yAvpW_zKJmI.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_yAvpW_zKJmI.json
# Processing enriched_YcoVwO2gRcE.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_YcoVwO2gRcE.json
# Processing enriched_YdmU2BO-544.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_YdmU2BO-544.json
# Processing enriched_ydT74SAts7M.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_ydT74SAts7M.json
# Processing enriched_yertm9lbyQY.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_yertm9lbyQY.json
# Processing enriched_YFLqFjY3Q5Y.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_YFLqFjY3Q5Y.json
# Processing enriched_YGNEVY062M0.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_YGNEVY062M0.json
# Processing enriched_YiDBLo2Ssbs.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_YiDBLo2Ssbs.json
# Processing enriched_yKgznPGg1R4.json with 11 chunks
# Upserted batch 1. Response: {'upserted_count': 11}
# Processed and stored embeddings for enriched_yKgznPGg1R4.json
# Processing enriched_ykMNii9vQDs.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_ykMNii9vQDs.json
# Processing enriched_ykQlXirszbo.json with 10 chunks
# Upserted batch 1. Response: {'upserted_count': 10}
# Processed and stored embeddings for enriched_ykQlXirszbo.json
# Processing enriched_YLR2Vm346Lc.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_YLR2Vm346Lc.json
# Processing enriched_ymCcs3lhiLs.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_ymCcs3lhiLs.json
# Processing enriched_yNltjUVf5Y0.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_yNltjUVf5Y0.json
# Processing enriched_YnPxMUYkVdU.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_YnPxMUYkVdU.json
# Processing enriched_YOiIOQsZjTs.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_YOiIOQsZjTs.json
# Processing enriched_yPiANlQxank.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_yPiANlQxank.json
# Processing enriched_yPrsuV3E-Dc.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_yPrsuV3E-Dc.json
# Processing enriched_YqFfh5IZUBs.json with 10 chunks
# Upserted batch 1. Response: {'upserted_count': 10}
# Processed and stored embeddings for enriched_YqFfh5IZUBs.json
# Processing enriched_Ys-JyytCu2s.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_Ys-JyytCu2s.json
# Processing enriched_yTAVUqs0_m0.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_yTAVUqs0_m0.json
# Processing enriched_yTWO2th-RIY.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_yTWO2th-RIY.json
# Processing enriched_YTXtAvWc39g.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_YTXtAvWc39g.json
# Processing enriched_yube4JjRK1E.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_yube4JjRK1E.json
# Processing enriched_yVeUYrRXU2E.json with 10 chunks
# Upserted batch 1. Response: {'upserted_count': 10}
# Processed and stored embeddings for enriched_yVeUYrRXU2E.json
# Processing enriched_YvKOvyiAdAI.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_YvKOvyiAdAI.json
# Processing enriched_YwFmEsa_lIk.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_YwFmEsa_lIk.json
# Processing enriched_yWjf2io_b6E.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_yWjf2io_b6E.json
# Processing enriched_yXGepG-viDg.json with 12 chunks
# Upserted batch 1. Response: {'upserted_count': 12}
# Processed and stored embeddings for enriched_yXGepG-viDg.json
# Processing enriched_Yz7Ofr9z1co.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_Yz7Ofr9z1co.json
# Processing enriched_Z-_ub4hWeZ4.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_Z-_ub4hWeZ4.json
# Processing enriched_Z0id0POSOkA.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_Z0id0POSOkA.json
# Processing enriched_z3bRVpy0VtE.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_z3bRVpy0VtE.json
# Processing enriched_Z59vr4av-hM.json with 9 chunks
# Upserted batch 1. Response: {'upserted_count': 9}
# Processed and stored embeddings for enriched_Z59vr4av-hM.json
# Processing enriched_ZA8GzhFh_CQ.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_ZA8GzhFh_CQ.json
# Processing enriched_ZaO3JJwxE88.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_ZaO3JJwxE88.json
# Processing enriched_zcJeHchdp9o.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_zcJeHchdp9o.json
# Processing enriched_ze01T1F-tFQ.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_ze01T1F-tFQ.json
# Processing enriched_ZEDY9QNBKe4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_ZEDY9QNBKe4.json
# Processing enriched_ZfawH9NsTtI.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_ZfawH9NsTtI.json
# Processing enriched_ZGhitttwdtY.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_ZGhitttwdtY.json
# Processing enriched_zGZVv5zqCFE.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_zGZVv5zqCFE.json
# Processing enriched_Zi6c09DRGxk.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_Zi6c09DRGxk.json
# Processing enriched_ziK69Q26CdA.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_ziK69Q26CdA.json
# Processing enriched_Zj9chziWUk8.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_Zj9chziWUk8.json
# Processing enriched_ZJGuZvY_Vak.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_ZJGuZvY_Vak.json
# Processing enriched_zJp2k5b_jk0.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched_zJp2k5b_jk0.json
# Processing enriched_zjYOcIbZ-Uo.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_zjYOcIbZ-Uo.json
# Processing enriched_zkQWXbAP9l0.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_zkQWXbAP9l0.json
# Processing enriched_ZLmUDtbe1O8.json with 11 chunks
# Upserted batch 1. Response: {'upserted_count': 11}
# Processed and stored embeddings for enriched_ZLmUDtbe1O8.json
# Processing enriched_zMgqxxuhd-Q.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_zMgqxxuhd-Q.json
# Processing enriched_ZNypibYUwD4.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_ZNypibYUwD4.json
# Processing enriched_zoKu5Bw9rLU.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_zoKu5Bw9rLU.json
# Processing enriched_Zo_1vTC4EbA.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_Zo_1vTC4EbA.json
# Processing enriched_zp1Fus-pgZo.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_zp1Fus-pgZo.json
# Processing enriched_Zp9i4DJmwNU.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_Zp9i4DJmwNU.json
# Processing enriched_zpfBxAUJwPU.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_zpfBxAUJwPU.json
# Processing enriched_ZqwwV2GIoO0.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_ZqwwV2GIoO0.json
# Processing enriched_ZrAiIvpZvhM.json with 11 chunks
# Upserted batch 1. Response: {'upserted_count': 11}
# Processed and stored embeddings for enriched_ZrAiIvpZvhM.json
# Processing enriched_zsmeXwHu6W0.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_zsmeXwHu6W0.json
# Processing enriched_ZsqVAPKcGZU.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched_ZsqVAPKcGZU.json
# Processing enriched_Zuork9xMYDE.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched_Zuork9xMYDE.json
# Processing enriched_zv0b069zgqo.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched_zv0b069zgqo.json
# Processing enriched_ZVQrODXR3xk.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched_ZVQrODXR3xk.json
# Processing enriched_ZWjBy6MGy0U.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_ZWjBy6MGy0U.json
# Processing enriched_ZxJlZxZ2KFw.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_ZxJlZxZ2KFw.json
# Processing enriched_zYiCYoL5UVI.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched_zYiCYoL5UVI.json
# Processing enriched_ZyNoQxdsLhw.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_ZyNoQxdsLhw.json
# Processing enriched_ZyWEXjdAGCQ.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched_ZyWEXjdAGCQ.json
# Processing enriched_zzD80vCLq0Y.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched_zzD80vCLq0Y.json
# Processing enriched__-SckJKAEQs.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched__-SckJKAEQs.json
# Processing enriched__9pWLqaULjQ.json with 8 chunks
# Upserted batch 1. Response: {'upserted_count': 8}
# Processed and stored embeddings for enriched__9pWLqaULjQ.json
# Processing enriched__Anl0osYkg8.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched__Anl0osYkg8.json
# Processing enriched__dOM7OMx8hA.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched__dOM7OMx8hA.json
# Processing enriched__dZZE4IiSxQ.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched__dZZE4IiSxQ.json
# Processing enriched__e1hQUxTAHc.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched__e1hQUxTAHc.json
# Processing enriched__fgxPmIo_dc.json with 7 chunks
# Upserted batch 1. Response: {'upserted_count': 7}
# Processed and stored embeddings for enriched__fgxPmIo_dc.json
# Processing enriched__iVBFlmBZKo.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched__iVBFlmBZKo.json
# Processing enriched__khs7_Z-zK4.json with 5 chunks
# Upserted batch 1. Response: {'upserted_count': 5}
# Processed and stored embeddings for enriched__khs7_Z-zK4.json
# Processing enriched__n_ZLU7q6w0.json with 3 chunks
# Upserted batch 1. Response: {'upserted_count': 3}
# Processed and stored embeddings for enriched__n_ZLU7q6w0.json
# Processing enriched__QdIgoJ1G0o.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched__QdIgoJ1G0o.json
# Processing enriched__qPZVaPXHKk.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched__qPZVaPXHKk.json
# Processing enriched__RWQ-iMEN1U.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched__RWQ-iMEN1U.json
# Processing enriched__Svs9G-jkhE.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched__Svs9G-jkhE.json
# Processing enriched__VzCnJW1Meg.json with 4 chunks
# Upserted batch 1. Response: {'upserted_count': 4}
# Processed and stored embeddings for enriched__VzCnJW1Meg.json
# Processing enriched__X244TMkCDI.json with 1 chunks
# Upserted batch 1. Response: {'upserted_count': 1}
# Processed and stored embeddings for enriched__X244TMkCDI.json
# Processing enriched__x5tKBtcH7g.json with 2 chunks
# Upserted batch 1. Response: {'upserted_count': 2}
# Processed and stored embeddings for enriched__x5tKBtcH7g.json
# Processing enriched__XH6TV4HZuc.json with 6 chunks
# Upserted batch 1. Response: {'upserted_count': 6}
# Processed and stored embeddings for enriched__XH6TV4HZuc.json
# Finished processing all chunks in E:\Udemy\fitness-podcastai\src\data_collection\data\raw\chunks
# Total vectors upserted: 5601
# Waiting for 60 seconds before checking total vectors...
# Total vectors in index: 5605
# Warning: Upserted 5601 vectors, but index shows 5605 vectors

# %%
# Querying example
query = "How to do a proper push-up"
results = collection.query(
    query_texts=[query],
    n_results=5
)

for doc, metadata in zip(results['documents'][0], results['metadatas'][0]):
    print(f"Document: {doc[:100]}...")
    print(f"Metadata: {metadata}")
    print("---")
